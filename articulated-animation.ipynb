# %%
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
# !sudo apt-get install git-lfs
# !git lfs install
# !git clone https://github.com/snap-research/articulated-animation/
# Out:
# Detected operating system as Ubuntu/jammy.
# Checking for curl...
# Detected curl...
# Checking for gpg...
# Detected gpg...
# Detected apt version as 2.4.13
# Running apt-get update... done.
# Installing apt-transport-https... done.
# Installing /etc/apt/sources.list.d/github_git-lfs.list...done.
# Importing packagecloud gpg key... Packagecloud gpg key imported to /etc/apt/keyrings/github_git-lfs-archive-keyring.gpg
# done.
# Running apt-get update... done.
#
# The repository is setup! You can now install packages.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages will be upgraded:
#   git-lfs
# 1 upgraded, 0 newly installed, 0 to remove and 47 not upgraded.
# Need to get 8,489 kB of archives.
# After this operation, 7,671 kB of additional disk space will be used.
# Get:1 https://packagecloud.io/github/git-lfs/ubuntu jammy/main amd64 git-lfs amd64 3.6.1 [8,489 kB]
# Fetched 8,489 kB in 0s (30.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 126217 files and directories currently installed.)
# Preparing to unpack .../git-lfs_3.6.1_amd64.deb ...
# Unpacking git-lfs (3.6.1) over (3.0.2-1ubuntu0.3) ...
# Setting up git-lfs (3.6.1) ...
# Git LFS initialized.
# Processing triggers for man-db (2.10.2-1) ...
# Git LFS initialized.
# Cloning into 'articulated-animation'...
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 157 (delta 8), reused 4 (delta 2), pack-reused 131 (from 1)
# Receiving objects: 100% (157/157), 46.93 MiB | 25.29 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
cd articulated-animation
# Out:
# /content/articulated-animation

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")

source_image = imageio.imread('sup-mat/source.png')
driving_video = imageio.mimread('sup-mat/driving.mp4')


source_image = resize(source_image, (384, 384))[..., :3]
driving_video = [resize(frame, (384, 384))[..., :3] for frame in driving_video]

def display(source, driving, generated=None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani


HTML(display(source_image, driving_video).to_html5_video())
# Out:
# <video width="800" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# 'Colab Notebooks'
#  CV_2.1.pdf
#  Diploma
#  msg1146777636-186138.jpg
#  photo_5285410136715814299_y.jpg
# 'Task №1 Весенние конкурсы.gdoc'
# 'Абитура КИ 2023.gsheet'
# 'АиЛОЦУ видео'
# 'Гайд для подготовки окружения к ЛР2 ИиУВМ'
#  Гороскоп.gdoc
# 'Копия 3_3_Устройства видео захвата.pdf'
# 'Копия приложение к приказу на технологическую практику (дневная ФО).docx'
# 'МППиУ лекции'
#  Мульт-quiz.gdoc
# 'Новая таблица.gsheet'
# 'Новогодняя викторина 2021-2022.gdoc'
# 'Новый документ (1).gdoc'
# 'Новый документ.gdoc'
# 'ОИнфБ лекции'
# 'Отчет опроса студентов 1 курса ВМСиС.gdoc'
# 'Отчет "Опрос первокурсников 2022".gdoc'
# 'ОУИС лекции'
# 'Протоколы ГЭК №1 (студенты дневной и заочной ФО) 2023-2024'
# 'Протоколы по дням'
#  Резюме.pdf
# 'Таска 2.gdoc'
# 'Таска Вадима.gsheet'
# 'Таска кульмасская на киновечер ближайший).gdoc'
# 'Таска намбер ту.gdoc'
# 'Точки на ДОД.gdoc'
#  Фото

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/Datasets"
# Out:
# birds  ted384.pth

# %%
from demo import load_checkpoints

generator, region_predictor, avd_network = load_checkpoints(config_path='config/ted384.yaml',
                                                            checkpoint_path='/content/drive/MyDrive/Colab Notebooks/Datasets/ted384.pth')

# %%
from demo import make_animation
from skimage import img_as_ubyte

predictions = make_animation(source_image, driving_video, generator,
                             region_predictor, avd_network, animation_mode='avd')

#save resulting video
imageio.mimsave('generated.mp4', [img_as_ubyte(frame) for frame in predictions])
#video can be downloaded from /content folder

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 133/133 [00:11<00:00, 11.51it/s]
# <video width="1200" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...
